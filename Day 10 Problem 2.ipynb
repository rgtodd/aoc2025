# %% [markdown]
# # Advent of Code - 2025 - Day 10 - Problem 2
#
# https://adventofcode.com/2025/day/10
#
# ## Load Source Data
#
# Load source data into `DATA`.

# %%
# Read the input file containing turn instructions
with open("data/day10.txt") as f:
    DATA = [line.strip() for line in f]

# DATA

# %% [markdown]
# ## Define Machine class
#
# Defines the state of a machine.
#
# We can determine the number of button presses required to produce the specified joltages by solving a series
# of linear equations. Example:
#
# ```
# buttons: [[3], [1, 3], [2], [2, 3], [0, 2], [0, 1]]
# valid_joltages: [3, 5, 4, 7]
#
# 0P0 + 0P1 + 0P2 + 0P3 + 1P4 + 1P5 = 3
# 0P0 + 1P1 + 0P2 + 0P3 + 0P4 + 1P5 = 5
# 0P0 + 0P1 + 1P2 + 1P3 + 1P4 + 0P5 = 4
# 1P0 + 1P1 + 0P2 + 1P3 + 0P4 + 0P5 = 7
# ```

# %%
from constraint.problem import Problem
from constraint.constraints import ExactSumConstraint, MaxSumConstraint
import re


class Machine:

    def __init__(self, definition: str):

        valid_lights, buttons, valid_joltages = Machine.parse_definition(definition)

        self.valid_lights = valid_lights
        self.buttons = buttons
        self.valid_joltages = valid_joltages

    @staticmethod
    def create_patterns() -> tuple[str, str]:

        ws = r"\s+"
        light_pattern = r"\[([.#]+)\]"
        button_pattern = r"\(([0-9,]+)\)"
        joltage_pattern = r"\{([0-9,]+)\}"

        # Regular expression pattern for the definition string
        line_pattern = (
            f"{light_pattern}((?:{ws}{button_pattern})+){ws}{joltage_pattern}"
        )

        # Regular expression for individual button definitions
        button_pattern = f"(?:{ws}({button_pattern}))"

        return (line_pattern, button_pattern)

    @staticmethod
    def parse_definition(
        definition: str,
    ) -> tuple[list[bool], list[list[int]], list[int]]:

        # Parse the overall definition string. Note that there are two results returned for the buttons due to the nested grouping constructs: the entire
        # button string as well as the last matched button.
        #
        definition_match = re.match(Machine.line_pattern, definition)
        assert definition_match
        buttons = definition_match.group(2)
        button_matches = re.findall(Machine.button_pattern, buttons)

        # Parse and convert the separate machine attributes.
        #
        valid_lights: list[bool] = [light == "#" for light in definition_match.group(1)]
        buttons = [
            list(map(int, button_match[1].split(",")))
            for button_match in button_matches
        ]
        joltages = list(map(int, definition_match.group(4).split(",")))

        return (valid_lights, buttons, joltages)
    
    def get_coeffcients(self) -> list[list[int]]:
    
        # Create a series of linear equations that express joltages in terms of the corresponding buttons.
        result = [[0 for _ in range(len(self.buttons))] for _ in range(len(self.valid_joltages))]
        for idx_button, button in enumerate(self.buttons):
            # print(f"button = {idx_button} - {button}")
            for idx_joltage in button:
                # print(f"  joltagle = {idx_joltage}")
                result[idx_joltage][idx_button] = 1

        return result
    
    def get_coeffcients2(self) -> list[list[int]]:
    
        result = [[0 for _ in range(len(self.buttons)+1)] for _ in range(len(self.valid_joltages))]
        for idx_button, button in enumerate(self.buttons):
            # print(f"button = {idx_button} - {button}")
            for idx_joltage in button:
                # print(f"  joltagle = {idx_joltage}")
                result[idx_joltage][idx_button] = 1
        for idx_joltage, joltage in enumerate(self.valid_joltages):
            result[idx_joltage][len(self.buttons)] = joltage

        return result
        
    def get_solutions(self):

        equations = self.get_coeffcients2()
        # j = self.valid_joltages

        print(equations)

        equations.sort(reverse=True)

        print(equations)

        max_joltage = max(self.valid_joltages)

        problem = Problem()
        for idx_button, button in enumerate(self.buttons):
            max_presses = min(self.valid_joltages[idx_joltage] for idx_joltage in button)
            problem.addVariable(idx_button, range(max_presses + 1))
        # problem.addVariables(range(len(self.buttons)), range(max_joltage + 1))
        for equation in equations:
            problem.addConstraint(ExactSumConstraint(equation[-1], equation[:-1]))
        problem.addConstraint(MaxSumConstraint(20))

        solutions = [problem.getSolution()]

        print(f"{len(solutions)} solutions found")

        return solutions
    
    def get_solution(self, max_presses):

        equations = self.get_coeffcients2()
        # j = self.valid_joltages

        # print(equations)

        equations.sort(reverse=True)

        # print(equations)

        max_joltage = max(self.valid_joltages)

        problem = Problem()
        for idx_button, button in enumerate(self.buttons):
            max_button_presses = min(self.valid_joltages[idx_joltage] for idx_joltage in button)
            # print(f"v{idx_button} max = {max_presses + 1}")
            problem.addVariable(idx_button, range(max_button_presses + 1))
        # problem.addVariables(range(len(self.buttons)), range(max_joltage + 1))
        problem.addConstraint(MaxSumConstraint(max_presses))
        for equation in equations:
            problem.addConstraint(ExactSumConstraint(equation[-1], equation[:-1]))

        solution = problem.getSolution()

        return solution
    
    def get_solution2(self):

        for max_presses in range(1, 25): # range(min(self.valid_joltages), 1000):
            print(f"Trying {max_presses}")
            try:
                solution = self.get_solution(max_presses)
                if solution != None:
                    return solution
            except ValueError:
                pass
    
    def get_min_button_presses(self):
        solutions = self.get_solutions()
        min_button_presses = min(sum(value for value in solution.values()) for solution in solutions)
        return min_button_presses

    line_pattern, button_pattern = create_patterns()

# %% [markdown]
# ## Solve All Machines
#
# Determine the minimum number of button presses required by all machines.

# %%
total = 0

for idx_joltage, specification in enumerate(DATA):
    print(f"Problem #{idx_joltage}")
    m = Machine(specification)
    solution = m.get_solution2()
    print(f"solution = {solution}")
    # button_presses = sum(value for value in solution.values())
    # print(f"button_presses = {button_presses}")
    # total += m.get_min_button_presses()
    # print(f"total = {total}")

total
# Out:
# Problem #0
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #1
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #2
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #3
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #4
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #5
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #6
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #7
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #8
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #9
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #10
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #11
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #12
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #13
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #14
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #15
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #16
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #17
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #18
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #19
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #20
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #21
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #22
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #23
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #24
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #25
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #26
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #27
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #28
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #29
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #30
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #31
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# solution = {0: 10, 1: 0}
# Problem #32
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #33
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #34
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #35
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #36
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #37
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #38
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #39
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #40
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #41
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #42
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #43
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #44
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #45
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #46
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #47
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #48
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #49
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #50
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #51
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #52
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #53
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #54
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #55
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #56
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #57
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #58
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #59
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #60
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #61
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #62
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #63
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #64
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #65
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #66
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #67
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #68
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# solution = None
# Problem #69
# Trying 1
# Trying 2
# Trying 3
# Trying 4
# Trying 5
# Trying 6
# Trying 7
# Trying 8
# Trying 9
# Trying 10
# Trying 11
# Trying 12
# Trying 13
# Trying 14
# Trying 15
# Trying 16
# Trying 17
# Trying 18
# Trying 19
# Trying 20
# Trying 21
# Trying 22
# Trying 23
# Trying 24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 6
#       4 print(f"Problem #{idx_joltage}")
#       5 m = Machine(specification)
# ----> 6 solution = m.get_solution2()
#       7 print(f"solution = {solution}")
#       8 # button_presses = sum(value for value in solution.values())
#       9 # print(f"button_presses = {button_presses}")
#      10 # total += m.get_min_button_presses()
#      11 # print(f"total = {total}")
#
# Cell In[45], line 143, in Machine.get_solution2(self)
#     141 print(f"Trying {max_presses}")
#     142 try:
# --> 143     solution = self.get_solution(max_presses)
#     144     if solution != None:
#     145         return solution
#
# Cell In[45], line 134, in Machine.get_solution(self, max_presses)
#     131 for equation in equations:
#     132     problem.addConstraint(ExactSumConstraint(equation[-1], equation[:-1]))
# --> 134 solution = problem.getSolution()
#     136 return solution
#
# File c:\Users\Rich\Source\repos\aoc2025\.venv\Lib\site-packages\constraint\problem.py:197, in Problem.getSolution(self)
#     195 if not domains:
#     196     return None
# --> 197 return self._solver.getSolution(domains, constraints, vconstraints)
#
# File c:\Users\Rich\Source\repos\aoc2025\.venv\Lib\site-packages\constraint\solvers.py:409, in OptimizedBacktrackingSolver.getSolution(self, domains, constraints, vconstraints)
#     407 iter = self.getSolutionIter(domains, constraints, vconstraints)
#     408 try:
# --> 409     return next(iter)
#     410 except StopIteration:
#     411     return None
#
# File c:\Users\Rich\Source\repos\aoc2025\.venv\Lib\site-packages\constraint\solvers.py:329, in OptimizedBacktrackingSolver.getSolutionIter(self, domains, constraints, vconstraints)
#     326         domain.pushState()
#     328 for constraint, variables in vconstraints[variable]:
# --> 329     if not constraint(variables, domains, assignments, pushdomains):
#     330         # Value is not good.
#     331         break
#     332 else:
#
# File c:\Users\Rich\Source\repos\aoc2025\.venv\Lib\site-packages\constraint\constraints.py:343, in ExactSumConstraint.__call__(self, variables, domains, assignments, forwardcheck)
#     341 for variable, multiplier in zip(variables, multipliers):
#     342     if variable in assignments:
# --> 343         sum += assignments[variable] * multiplier
#     344     else:
#     345         min_sum_missing += self._var_min[variable]
#
# KeyboardInterrupt:
