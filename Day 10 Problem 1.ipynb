# %% [markdown]
# # Advent of Code - 2025 - Day 10 - Problem 1
#
# https://adventofcode.com/2025/day/10
#
# ## Load Source Data
#
# Load source data into `DATA`.

# %%
# Read the input file containing turn instructions
with open("data/sampleDay10.txt") as f:
    DATA = [line.strip() for line in f]

DATA
# Out:
# ['[.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}',
#  '[...#.] (0,2,3,4) (2,3) (0,4) (0,1,2) (1,2,3,4) {7,5,12,7,2}',
#  '[.###.#] (0,1,2,3,4) (0,3,4) (0,1,2,4,5) (1,2) {10,11,11,5,10,5}']

# %% [markdown]
# ## Define Machine class
#
# Defines the state of a machine.

# %%
import re

class Machine:

    def __init__(self, definition: str):

        lights, buttons, joltages = Machine.parse_definition(definition)

        self.lights = lights
        self.buttons = buttons
        self.joltages = joltages

        # definition_match = re.match(Machine.line_pattern, definition)
        # if definition_match:
        #     print(f"✓ Matched: {definition} = {definition_match.groups()}")
        #     buttons = definition_match.group(2)
        #     button_matches = re.findall(Machine.button_pattern, buttons)
        #     print(f"✓ Matched: {buttons} = {button_matches}")
        #     # print(button_matches)
        #     # button_match = re.match(Machine.button_pattern, buttons)
        #     # if (button_match):
        #     #     print(f"✓ Matched: {buttons} = {button_match.groups()}")
        # else:
        #     print(f"✗ Failed to match: {definition}")

    @staticmethod
    def create_patterns() -> tuple[str, str]:

        ws = r'\s+'
        light_pattern = r'\[([.#]+)\]'
        button_pattern = r'\(([0-9,]+)\)'
        joltage_pattern = r'\{([0-9,]+)\}'

        # Regular expression pattern for the definition string
        line_pattern = f"{light_pattern}((?:{ws}{button_pattern})+){ws}{joltage_pattern}"

        # Regular expression for inidivual button definitions
        button_pattern = f"(?:{ws}({button_pattern}))"

        return (line_pattern, button_pattern)
    
    @staticmethod
    def parse_definition(definition: str) -> tuple[list[str], list[list[int]], list[int]]:

        definition_match = re.match(Machine.line_pattern, definition)
        assert definition_match

        buttons = definition_match.group(2)
        button_matches = re.findall(Machine.button_pattern, buttons)
        # print (button_matches)

        # print(definition_match.group(1))
        lights: list[str] = list(definition_match.group(1))

        buttons = [list(map(int, button_match[1].split(","))) for button_match in button_matches]
        # print (buttons)

        print (definition_match.group(4))
        joltages = list(map(int, definition_match.group(4).split(",")))
        print(joltages)

        return (lights, buttons, joltages)
    
    line_pattern, button_pattern = create_patterns()


for line in DATA:
    m = Machine(line)
    for attr, value in vars(m).items():
        print(f"{attr}: {value}")
# Out:
# 3,5,4,7
# [3, 5, 4, 7]
# lights: ['.', '#', '#', '.']
# buttons: [[3], [1, 3], [2], [2, 3], [0, 2], [0, 1]]
# joltages: [3, 5, 4, 7]
# 7,5,12,7,2
# [7, 5, 12, 7, 2]
# lights: ['.', '.', '.', '#', '.']
# buttons: [[0, 2, 3, 4], [2, 3], [0, 4], [0, 1, 2], [1, 2, 3, 4]]
# joltages: [7, 5, 12, 7, 2]
# 10,11,11,5,10,5
# [10, 11, 11, 5, 10, 5]
# lights: ['.', '#', '#', '#', '.', '#']
# buttons: [[0, 1, 2, 3, 4], [0, 3, 4], [0, 1, 2, 4, 5], [1, 2]]
# joltages: [10, 11, 11, 5, 10, 5]
