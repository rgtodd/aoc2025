# %% [markdown]
# # Advent of Code - 2025 - Sample Day 1 - Problem 1
#
# https://adventofcode.com/2024/day/1
#
# ## Load Source Data
#
# Load source data into `DATA`.
#
# Parse each "column" of values into `list1` and `list2`.

# %%
f = open("data/sampleDay1.txt", "r")
DATA = list(map(str.strip, f.readlines()))
f.close()

# Parse list of values and separate into list1 and list2
#
list1 = []
list2 = []
for line in DATA:
    values = line.split()
    list1.append(int(values[0]))
    list2.append(int(values[1]))

assert len(list1) == 1000
assert len(list2) == 1000

# %% [markdown]
# ## Sort Lists
#
# Sort `list1` and `list2`.

# %%
list1.sort()
list2.sort()

# %% [markdown]
# ## Compute Distances
#
# Determine the distances between each pair of values.

# %%
total_distance = 0
for idx in range(0, len(list1)):
    total_distance += abs(list1[idx] - list2[idx])

print(f"totalDistance = {total_distance}")
# Out:
# totalDistance = 2057374
